# %% [markdown]
# # Truncation Nation - Hack4Change

# %%
import pandas as pd

# Air Traffic Data
air_traffic = pd.read_csv('data/cleaned/irish_flights.csv', parse_dates = True)
air_traffic

# Covid Cases Data
covid_cases = pd.read_csv('data/cleaned/covid_stats.csv', parse_dates = True)
covid_cases
# Out:
#      Unnamed: 0  ConfirmedCovidCases  TotalConfirmedCovidCases  \
# 0    2020-02-29                    1                         1
# 1    2020-03-03                    1                         2
# 2    2020-03-04                    4                         6
# 3    2020-03-05                    7                        13
# 4    2020-03-06                    5                        18
# ..          ...                  ...                       ...
# 299  2020-12-26                 1296                     85394
# 300  2020-12-27                  744                     86129
# 301  2020-12-28                  765                     86894
# 302  2020-12-29                 1546                     88439
# 303  2020-12-30                 1718                     90157
#
#      ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# 0                       0                 0                     NaN
# 1                       0                 0                     NaN
# 2                       0                 0                     NaN
# 3                       0                 0                     NaN
# 4                       0                 0                     NaN
# ..                    ...               ...                     ...
# 299                     6              2200                  5837.0
# 300                     4              2204                  5840.0
# 301                     1              2205                  5873.0
# 302                     9              2213                  5898.0
# 303                    13              2226                  5932.0
#
#      TravelAbroad
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 299           1.0
# 300           1.0
# 301           1.0
# 302           1.0
# 303           1.0
#
# [304 rows x 7 columns]

# %%
air_traffic
# Out:
#        Day 2020  Flights 2020 7-day moving average Flights 2020
# 0    2020-03-01           747                               693
# 1    2020-03-02           762                               694
# 2    2020-03-03           645                       696,8571429
# 3    2020-03-04           648                       698,1428571
# 4    2020-03-05           708                       697,5714286
# ..          ...           ...                               ...
# 292  2020-12-18           315                       182,8571429
# 293  2020-12-19           250                       199,8571429
# 294  2020-12-20           266                       215,2857143
# 295  2020-12-21           202                       219,5714286
# 296  2020-12-22           184                       224,7142857
#
# [297 rows x 3 columns]

# %%
air_traffic2 = air_traffic.drop([0,1], axis = 0)
air_traffic2.head()
# Out:
#      Day 2020  Flights 2020 7-day moving average Flights 2020
# 2  2020-03-03           645                       696,8571429
# 3  2020-03-04           648                       698,1428571
# 4  2020-03-05           708                       697,5714286
# 5  2020-03-06           762                       693,4285714
# 6  2020-03-07           608                       697,1428571

# %%
covid_cases2 = covid_cases.drop([0], axis = 0)
covid_cases2.head()
# Out:
#    Unnamed: 0  ConfirmedCovidCases  TotalConfirmedCovidCases  \
# 1  2020-03-03                    1                         2
# 2  2020-03-04                    4                         6
# 3  2020-03-05                    7                        13
# 4  2020-03-06                    5                        18
# 5  2020-03-07                    1                        19
#
#    ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# 1                     0                 0                     NaN
# 2                     0                 0                     NaN
# 3                     0                 0                     NaN
# 4                     0                 0                     NaN
# 5                     0                 0                     NaN
#
#    TravelAbroad
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %%
air_traffic2.rename(columns = {'Day 2020':'Date'}, inplace = True)
air_traffic2.head()
# Out:
#          Date  Flights 2020 7-day moving average Flights 2020
# 2  2020-03-03           645                       696,8571429
# 3  2020-03-04           648                       698,1428571
# 4  2020-03-05           708                       697,5714286
# 5  2020-03-06           762                       693,4285714
# 6  2020-03-07           608                       697,1428571

# %%
covid_cases2.rename(columns = {'Unnamed: 0':'Date'}, inplace = True)
covid_cases2.head()
# Out:
#          Date  ConfirmedCovidCases  TotalConfirmedCovidCases  \
# 1  2020-03-03                    1                         2
# 2  2020-03-04                    4                         6
# 3  2020-03-05                    7                        13
# 4  2020-03-06                    5                        18
# 5  2020-03-07                    1                        19
#
#    ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# 1                     0                 0                     NaN
# 2                     0                 0                     NaN
# 3                     0                 0                     NaN
# 4                     0                 0                     NaN
# 5                     0                 0                     NaN
#
#    TravelAbroad
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %%
df = covid_cases2

# %%
df.set_index("Date", inplace = True)
df.head()
# Out:
#             ConfirmedCovidCases  TotalConfirmedCovidCases  \
# Date
# 2020-03-03                    1                         2
# 2020-03-04                    4                         6
# 2020-03-05                    7                        13
# 2020-03-06                    5                        18
# 2020-03-07                    1                        19
#
#             ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# Date
# 2020-03-03                     0                 0                     NaN
# 2020-03-04                     0                 0                     NaN
# 2020-03-05                     0                 0                     NaN
# 2020-03-06                     0                 0                     NaN
# 2020-03-07                     0                 0                     NaN
#
#             TravelAbroad
# Date
# 2020-03-03           NaN
# 2020-03-04           NaN
# 2020-03-05           NaN
# 2020-03-06           NaN
# 2020-03-07           NaN

# %%
air_traffic2.set_index("Date", inplace = True)
air_traffic2.head()
# Out:
#             Flights 2020 7-day moving average Flights 2020
# Date
# 2020-03-03           645                       696,8571429
# 2020-03-04           648                       698,1428571
# 2020-03-05           708                       697,5714286
# 2020-03-06           762                       693,4285714
# 2020-03-07           608                       697,1428571
# ...                  ...                               ...
# 2020-12-18           315                       182,8571429
# 2020-12-19           250                       199,8571429
# 2020-12-20           266                       215,2857143
# 2020-12-21           202                       219,5714286
# 2020-12-22           184                       224,7142857
#
# [295 rows x 2 columns]

# %%
air_traffic2.drop(['7-day moving average Flights 2020'], axis = 'columns', inplace = True)
air_traffic2.head()
# Out:
#             Flights 2020
# Date
# 2020-03-03           645
# 2020-03-04           648
# 2020-03-05           708
# 2020-03-06           762
# 2020-03-07           608

# %%
df = pd.merge(air_traffic2,covid_cases2,left_index=True,right_index=True)
df.head()
# Out:
#             Flights 2020  ConfirmedCovidCases  TotalConfirmedCovidCases  \
# Date
# 2020-03-03           645                    1                         2
# 2020-03-04           648                    4                         6
# 2020-03-05           708                    7                        13
# 2020-03-06           762                    5                        18
# 2020-03-07           608                    1                        19
#
#             ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# Date
# 2020-03-03                     0                 0                     NaN
# 2020-03-04                     0                 0                     NaN
# 2020-03-05                     0                 0                     NaN
# 2020-03-06                     0                 0                     NaN
# 2020-03-07                     0                 0                     NaN
#
#             TravelAbroad
# Date
# 2020-03-03           NaN
# 2020-03-04           NaN
# 2020-03-05           NaN
# 2020-03-06           NaN
# 2020-03-07           NaN

# %%
df.tail()
# Out:
#             Flights 2020  ConfirmedCovidCases  TotalConfirmedCovidCases  \
# Date
# 2020-12-18           315                  582                     78254
# 2020-12-19           250                  527                     78776
# 2020-12-20           266                  764                     79542
# 2020-12-21           202                  727                     80267
# 2020-12-22           184                  970                     81228
#
#             ConfirmedCovidDeaths  TotalCovidDeaths  HospitalisedCovidCases  \
# Date
# 2020-12-18                     6              2149                  5549.0
# 2020-12-19                     5              2154                  5570.0
# 2020-12-20                     4              2158                  5595.0
# 2020-12-21                     0              2158                  5615.0
# 2020-12-22                    13              2171                  5653.0
#
#             TravelAbroad
# Date
# 2020-12-18           1.0
# 2020-12-19           1.0
# 2020-12-20           1.0
# 2020-12-21           1.0
# 2020-12-22           1.0

# %%
# importing useful packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p = df.plot(title = 'Travel and Covid Cases',figsize = (14, 6), fontsize = 12)
p.set_xlabel('date')
p.set_ylabel('');

# %%
p = df['Flights 2020'].plot(title = 'Flights vs Confirmed Covid Cases',figsize = (14, 6), fontsize = 12)
df['ConfirmedCovidCases'].plot()
p.set_xlabel('date')
plt.legend(['Flights 2020','Confirmed Covid Cases'])
p.set_ylabel('');
